# %%
from Calibration_class import IBM4Calibrator


Cal = IBM4Calibrator()
Cal.calibrate()
# Out:
# Validating inputs...
# Communication with: /dev/ttyACM1  is open
# Starting calibration process...
# Running waveform sweep for current increase...
# Computing max supported A0 voltages based on resistor and k-factor...
# Measuring increase waveform for A0=0.01 V, A1=3.25 V...
# Smoothing signal with moving average...
# Performing plateau detection on waveform...
# Measuring increase waveform for A0=0.02 V, A1=3.25 V...
# Smoothing signal with moving average...
# Performing plateau detection on waveform...
# Measuring increase waveform for A0=0.03 V, A1=3.25 V...
# Smoothing signal with moving average...
# Performing plateau detection on waveform...
# Measuring increase waveform for A0=0.06 V, A1=3.25 V...
# Smoothing signal with moving average...
# Performing plateau detection on waveform...
# Measuring increase waveform for A0=0.1 V, A1=3.25 V...
# Smoothing signal with moving average...
# Performing plateau detection on waveform...
# Measuring increase waveform for A0=0.3 V, A1=3.25 V...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 5
#       1 from Calibration_class import IBM4Calibrator
#       4 Cal = IBM4Calibrator()
# ----> 5 Cal.calibrate()
#
# File ~/Code/Summer_intern_ship_IBM4/Current_Calibration_IBM4/Calibration_class.py:53, in calibrate(self)
#      46 """
#      47 High-level calibration entry point.
#      48 Performs waveform-based response-time measurement,
#      49 then runs CurCal to compute calibration factor and save results.
#      50 """
#      52 self.run_waveform_sweep_increase()
# ---> 53 # self.run_waveform_sweep_decrease()
#      55 self.run_current_cal()
#      57 return dict(self.waveform_plateau_times)
#
# File ~/Code/Summer_intern_ship_IBM4/Current_Calibration_IBM4/Calibration_class.py:100, in run_waveform_sweep_increase(self)
#      95     raise ValueError("resistor is too large (or approx_k_factor too high); "
#      96                      "max supported A0 is below 0.1 V")
#      98 for A0_voltage in A0_values:
#      99     rt_dict = self._read_waveform_current_increase(
# --> 100         A0_voltage=A0_voltage,
#     101         A1_voltage=A1_voltage,
#     102         response_times=self.waveform_plateau_times,
#     103     )
#     104     self.waveform_plateau_times.update(rt_dict)
#
# File ~/Code/Summer_intern_ship_IBM4/Current_Calibration_IBM4/Calibration_class.py:152, in _read_waveform_current_increase(self, A0_voltage, A1_voltage, response_times)
#     150 start = time.time()
#     151 avg, err, vals = self.the_dev.ReadVoltage(input_ch, "Multiple Voltage", Nreads)
# --> 152 end = time.time()
#     154 deltaT = end - start
#     155 measurement_time = deltaT / float(Nreads)
#
# File ~/Code/Summer_intern_ship_IBM4/Current_Calibration_IBM4/IBM4_Lib.py:539, in Ser_Iface.ReadVoltage(self, input_channel, read_type, no_reads)
#     537     return self.ReadSingleVoltage(input_channel)
#     538 elif read_type == 'Multiple Voltage':
# --> 539     return self.ReadMultipleVoltage(input_channel, no_reads)
#     540 elif read_type == 'Average Voltage':
#     541     return self.ReadAverageVoltage(input_channel, no_reads)
#
# File ~/Code/Summer_intern_ship_IBM4/Current_Calibration_IBM4/IBM4_Lib.py:861, in Ser_Iface.ReadMultipleVoltage(self, input_channel, no_reads, loud)
#     859 self.instr_obj.write( str.encode(read_cmd) ) # when using serial str must be encoded as bytes
#     860 read_result = self.instr_obj.read_until(size=read_cmd.__sizeof__()) # read_result returned as bytes and clear the return message
# --> 861 read_result = self.instr_obj.read_until(b'\n',size=None) # read_result returned as bytes, must be cast to str before being parsed
#     862 vals_str = re.findall(r'[-+]?\d+[\.]?\d*', str(read_result) ) # parse the numeric values of read_result into a list
#     863 vals_flt = numpy.float64(vals_str[-no_reads:]) # convert the list of strings to floats using numpy, save as numpy array (better)
#
# File /usr/lib/python3/dist-packages/serial/serialutil.py:663, in SerialBase.read_until(self, expected, size)
#     661 timeout = Timeout(self._timeout)
#     662 while True:
# --> 663     c = self.read(1)
#     664     if c:
#     665         line += c
#
# File /usr/lib/python3/dist-packages/serial/serialposix.py:565, in Serial.read(self, size)
#     563 while len(read) < size:
#     564     try:
# --> 565         ready, _, _ = select.select([self.fd, self.pipe_abort_read_r], [], [], timeout.time_left())
#     566         if self.pipe_abort_read_r in ready:
#     567             os.read(self.pipe_abort_read_r, 1000)
#
# KeyboardInterrupt:

# %%
Cal.Get_saved_values("c")
# Out:
# Retrieving calibration data from IBM4 firmware...
# Communication with: /dev/ttyACM0  is open
# 1
# Closing Serial link with: /dev/ttyACM0
# '1'

# %% [markdown]
# ## update local branch names and stuff
#
# git fetch --all --prune

# %% [markdown]
# ## update github branch
# git push --set-upstream origin <branch_name> # if the branch doesnt exist yet
#
# git push # if the branch already exist
#
#
# git checkout branch-name # check if up to date

# %% [markdown]
# # update online branch
#
# git checkout Cal_Class
#
# git fetch origin
#
# git pull origin Cal_Class
#
# git add .
#
# git commit -m "working calibration for increaseing current"
#
# git push origin Cal_Class
