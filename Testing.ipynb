# %%
import Control_Examples 

print("\n")

Control_Examples.calibrate(resistor = 50,show_plots = True)

# Control_Examples.Get_cal("Cal")

print("\n")
# Out:
# Communication with: /dev/ttyACM0  is open
#
#
#  {0.02: 0.4991, 0.03: 0.2568, 0.04: 0.2093, 0.05: 0.1617, 0.1: 0.1329, 0.2: 0.1146, 0.3: 0.0997, 0.4: 0.1006, 0.5: 0.0759, 0.6: 0.0756, 0.7: 0.0767} True 50.0 90.0
#
#
# 50.0 90.0 0.7
# 0.0000 V - delay of 0.50 seconds
# 0.0203 V - delay of 0.26 seconds
# 0.0304 V - delay of 0.21 seconds
# 0.0406 V - delay of 0.16 seconds
# 0.0507 V - delay of 0.13 seconds
# 0.1014 V - delay of 0.11 seconds
# 0.2029 V - delay of 0.10 seconds
# 0.3043 V - delay of 0.10 seconds
# 0.4058 V - delay of 0.08 seconds
# 0.5072 V - delay of 0.08 seconds
# 0.6087 V - delay of 0.08 seconds
# Sweep complete
# Cal_factor:  [ 8.35959211e+01 -5.10444384e-02]
#
# Calibration results saved to IBM4.
# Error: Control_Examples.calibrate()
# 'cal'
# Closing Serial link with: /dev/ttyACM0

# %% [markdown]
# ## update local branch names and stuff
#
# git fetch --all --prune

# %% [markdown]
# ## update github branch
# git push --set-upstream origin <branch_name> # if the branch doesnt exist yet
#
# git push # if the branch already exist
#
#
# git checkout branch-name # check if up to date
