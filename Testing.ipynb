# %% [markdown]
# ## update local branch names and stuff
#
# git fetch --all --prune

# %% [markdown]
# ## update github branch
# git push --set-upstream origin <branch_name> # if the branch doesnt exist yet
#
# git push # if the branch already exist
#
#
# git checkout branch-name # check if up to date

# %% [markdown]
# # update online branch
#
# git checkout working_current_source
#
# git fetch origin
#
# git pull origin working_current_source
#
# git add .
#
# git commit -m "This is a working version of the Current out, need to add more pre defined operations to make it better"
#
# git push origin working_current_source
